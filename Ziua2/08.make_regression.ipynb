# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
regression_data = make_regression(n_samples=2, n_features=3)   
len(regression_data)
# Out:
# 2

# %%
x, y = regression_data
x.shape, y.shape
# Out:
# ((2, 3), (2,))

# %%
x
# Out:
# array([[-1.36197157,  0.81789306, -0.6842302 ],
#        [ 0.14781061, -0.25064232,  0.09079316]])

# %%
y
# Out:
# array([-66.97619957,  -3.21743613])

# %%
regression_data = make_regression(n_samples=10, n_features=1)   
len(regression_data)
x, y = regression_data
plt.scatter(x, y);

# %%
regression_data = make_regression(n_samples=100, n_features=1)   
len(regression_data)
x, y = regression_data
plt.scatter(x, y);
plt.plot(x, y);

# %%
regression_data = make_regression(n_samples=100, n_features=1, noise=10)   
len(regression_data)
x, y = regression_data
plt.scatter(x, y);

# %%
regression_data = make_regression(n_samples=100, n_features=1, noise=10)   
len(regression_data)
x, y = regression_data
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
lin_model = LinearRegression()
lin_model
# Out:
# LinearRegression()

# %%
lin_model.fit(x, y)
# Out:
# LinearRegression()

# %%
lin_model.predict([[0]])
# Out:
# array([-0.12155114])

# %%
knn_model = KNeighborsRegressor()
knn_model
# Out:
# KNeighborsRegressor()

# %%
knn_model.fit(x, y)
# Out:
# KNeighborsRegressor()

# %%
knn_model.predict([[0]])
# Out:
# array([3.60061326])
