# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
apartamente = np.array([
    [27, 80_000], [35, 60_000], [41, 65_000], [50, 70_000],   [50, 100_000], [60, 80_000], [75, 90_000],  [70, 120_000], [110, 110_000]
])
suprafete = apartamente[ : , 0]
preturi = apartamente [ : , 1]

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
x = suprafete
y = preturi

# %%
print("x=", x)
print("y=", y)
# Out:
# x= [ 27  35  41  50  50  60  75  70 110]
# y= [ 80000  60000  65000  70000 100000  80000  90000 120000 110000]

# %% [markdown]
# [ 27  35  41  50  50  60  75  70 110]

# %% [markdown]
# [[27],  [35]  [41]  [50],  [50],  [60],  [75],  [70], [110]]

# %%
x = suprafete.reshape((-1, 1))
y = preturi

print("x=", x)
print("y=", y)
# Out:
# x= [[ 27]
#  [ 35]
#  [ 41]
#  [ 50]
#  [ 50]
#  [ 60]
#  [ 75]
#  [ 70]
#  [110]]
# y= [ 80000  60000  65000  70000 100000  80000  90000 120000 110000]

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.predict([  [77], [100]    ])
# Out:
# array([ 97167.84833539, 110246.38893782])

# %%
model.coef_
# Out:
# array([568.63220011])

# %%
model.intercept_
# Out:
# np.float64(53383.1689272503)

# %%
def f_sklearn(x):
    return model.coef_ * x + model.intercept_

# %%
from scipy import stats
result = stats.linregress(suprafete, preturi)
slope = result.slope
intercept = result.intercept

# %%
def f_scipy(x):
    return result.slope * x + result.intercept

# %%
plt.scatter(suprafete, preturi)
plt.plot(suprafete, preturi)

plt.plot(suprafete, model.coef_ * suprafete + model.intercept_, c="black")
plt.plot(suprafete, result.slope * suprafete + result.intercept, c="red")
