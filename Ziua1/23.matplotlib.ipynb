# %% [markdown]
# # pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter([1, 2, 3], [4, 5, 6])

# %%
plt.scatter([1, 2, 3], [4, 5, 6]); # cu ; se inchide graficul
x

# %%
x = [1, 2, 3]
y = [4, 5, 6]
plt.scatter(x, y);

# %%
import numpy as np

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])
plt.scatter(x, y);

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])
plt.plot(x, y);

# %%
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])
plt.plot(x, y);
plt.scatter(x, y);

# %%
x = np.array([1, 2, 3, 4])
y = np.array([4, 5, 6, 7])
plt.plot(x, y);
plt.scatter(x, y);

# %%
x = np.array([1, 2, 3, 4])
y = np.array([4, 4, 6, 7])
plt.plot(x, y);
plt.scatter(x, y);
