# %%
import requests

# %%
response = requests.get("https://dummyjson.com/recipes")

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content
# Out:
# b'{"recipes":[{"id":1,"name":"Classic Margherita Pizza","ingredients":["Pizza dough","Tomato sauce","Fresh mozzarella cheese","Fresh basil leaves","Olive oil","Salt and pepper to taste"],"instructions":["Preheat the oven to 475\xc2\xb0F (245\xc2\xb0C).","Roll out the pizza dough and spread tomato sauce evenly.","Top with slices of fresh mozzarella and fresh basil leaves.","Drizzle with olive oil and season with salt and pepper.","Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.","Slice and serve hot."],"prepTimeMinutes":20,"cookTimeMinutes":15,"servings":4,"difficulty":"Easy","cuisine":"Italian","caloriesPerServing":300,"tags":["Pizza","Italian"],"userId":166,"image":"https://cdn.dummyjson.com/recipe-images/1.webp","rating":4.6,"reviewCount":98,"mealType":["Dinner"]},{"id":2,"name":"Vegetarian Stir-Fry","ingredients":["Tofu, cubed","Broccoli florets","Carrots, sliced","Bell peppers, sliced","Soy sauce","Ginger, minced","Garlic, minced","Sesame oil","Co
# ...

# %%
type(response.content)
# Out:
# bytes

# %%
json_response = response.json()
json_response
# Out:
# {'recipes': [{'id': 1,
#    'name': 'Classic Margherita Pizza',
#    'ingredients': ['Pizza dough',
#     'Tomato sauce',
#     'Fresh mozzarella cheese',
#     'Fresh basil leaves',
#     'Olive oil',
#     'Salt and pepper to taste'],
#    'instructions': ['Preheat the oven to 475°F (245°C).',
#     'Roll out the pizza dough and spread tomato sauce evenly.',
#     'Top with slices of fresh mozzarella and fresh basil leaves.',
#     'Drizzle with olive oil and season with salt and pepper.',
#     'Bake in the preheated oven for 12-15 minutes or until the crust is golden brown.',
#     'Slice and serve hot.'],
#    'prepTimeMinutes': 20,
#    'cookTimeMinutes': 15,
#    'servings': 4,
#    'difficulty': 'Easy',
#    'cuisine': 'Italian',
#    'caloriesPerServing': 300,
#    'tags': ['Pizza', 'Italian'],
#    'userId': 166,
#    'image': 'https://cdn.dummyjson.com/recipe-images/1.webp',
#    'rating': 4.6,
#    'reviewCount': 98,
#    'mealType': ['Dinner']},
#   {'id': 2,
# ...

# %%
type(json_response)
# Out:
# dict

# %%
json_response.keys()
# Out:
# dict_keys(['recipes', 'total', 'skip', 'limit'])

# %%
type(json_response["recipes"])
# Out:
# list

# %%
import pandas as pd

# %%
recipes_df = pd.DataFrame(json_response["recipes"])
recipes_df.head()
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
# 2   3    Chocolate Chip Cookies
# 3   4     Chicken Alfredo Pasta
# 4   5       Mango Salsa Chicken
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
# 2  [All-purpose flour, Butter, softened, Brown su...
# 3  [Fettuccine pasta, Chicken breast, sliced, Hea...
# 4  [Chicken thighs, Mango, diced, Red onion, fine...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
# 2  [Preheat the oven to 350°F (175°C)., In a bowl...               15
# 3  [Cook fettuccine pasta according to package in...               15
# 4  [Season chicken thighs with salt and pepper., ...               15
#
# ...

# %%
recipes_df.tail()
# Out:
#     id                         name  \
# 25  26  Mexican Street Corn (Elote)
# 26  27              Russian Borscht
# 27  28     South Indian Masala Dosa
# 28  29        Lebanese Falafel Wrap
# 29  30         Brazilian Caipirinha
#
#                                           ingredients  \
# 25  [Corn on the cob, Mayonnaise, Cotija cheese, c...
# 26  [Beets, peeled and shredded, Cabbage, shredded...
# 27  [Dosa batter (fermented rice and urad dal batt...
# 28  [Falafel balls, Whole wheat or regular wraps, ...
# 29  [Cachaça (Brazilian sugarcane spirit), Lime, c...
#
#                                          instructions  prepTimeMinutes  \
# 25  [Grill or roast corn on the cob until kernels ...               15
# 26  [In a pot, sauté chopped onions and garlic unt...               30
# 27  [In a pan, heat ghee and add mustard seeds, cu...               40
# 28  [Warm falafel balls according to package instr...               15
# ...

# %%
recipes_df.tail(2)
# Out:
#     id                   name  \
# 28  29  Lebanese Falafel Wrap
# 29  30   Brazilian Caipirinha
#
#                                           ingredients  \
# 28  [Falafel balls, Whole wheat or regular wraps, ...
# 29  [Cachaça (Brazilian sugarcane spirit), Lime, c...
#
#                                          instructions  prepTimeMinutes  \
# 28  [Warm falafel balls according to package instr...               15
# 29  [In a glass, muddle lime wedges with granulate...                5
#
#     cookTimeMinutes  servings difficulty    cuisine  caloriesPerServing  \
# 28               10         2       Easy   Lebanese                 400
# 29                0         1       Easy  Brazilian                 150
#
#                                  tags  userId  \
# 28          [Falafel, Lebanese, Wrap]     110
# 29  [Caipirinha, Brazilian, Cocktail]     134
#
#                                               image  rating  reviewCount  \
# ...

# %%
recipes_df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
recipes_df.keys()
# Out:
# Index(['id', 'name', 'ingredients', 'instructions', 'prepTimeMinutes',
#        'cookTimeMinutes', 'servings', 'difficulty', 'cuisine',
#        'caloriesPerServing', 'tags', 'userId', 'image', 'rating',
#        'reviewCount', 'mealType'],
#       dtype='object')

# %%
recipes_df.count()
# Out:
# id                    30
# name                  30
# ingredients           30
# instructions          30
# prepTimeMinutes       30
# cookTimeMinutes       30
# servings              30
# difficulty            30
# cuisine               30
# caloriesPerServing    30
# tags                  30
# userId                30
# image                 30
# rating                30
# reviewCount           30
# mealType              30
# dtype: int64

# %%
recipes_df.dtypes
# Out:
# id                      int64
# name                   object
# ingredients            object
# instructions           object
# prepTimeMinutes         int64
# cookTimeMinutes         int64
# servings                int64
# difficulty             object
# cuisine                object
# caloriesPerServing      int64
# tags                   object
# userId                  int64
# image                  object
# rating                float64
# reviewCount             int64
# mealType               object
# dtype: object

# %%
recipes_df.describe()
# Out:
#               id  prepTimeMinutes  cookTimeMinutes   servings  \
# count  30.000000        30.000000        30.000000  30.000000
# mean   15.500000        21.500000        19.500000   4.366667
# std     8.803408         9.751216        12.821722   3.978245
# min     1.000000         5.000000         0.000000   1.000000
# 25%     8.250000        15.000000        11.250000   3.000000
# 50%    15.500000        20.000000        20.000000   4.000000
# 75%    22.750000        30.000000        28.750000   4.000000
# max    30.000000        45.000000        45.000000  24.000000
#
#        caloriesPerServing      userId     rating  reviewCount
# count           30.000000   30.000000  30.000000    30.000000
# mean           331.333333  107.633333   4.616667    51.633333
# std            122.776313   57.135340   0.219848    30.673456
# min            120.000000    1.000000   4.200000     0.000000
# 25%            227.500000   55.750000   4.425000    27.000000
# ...

# %%
recipes_df["cookTimeMinutes"].mean()
# Out:
# np.float64(19.5)

# %%
recipes_df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
type(recipes_df.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
recipes_df.describe().keys()
# Out:
# Index(['id', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
#        'caloriesPerServing', 'userId', 'rating', 'reviewCount'],
#       dtype='object')

# %%
recipes_df.head(2)
# Out:
#    id                      name  \
# 0   1  Classic Margherita Pizza
# 1   2       Vegetarian Stir-Fry
#
#                                          ingredients  \
# 0  [Pizza dough, Tomato sauce, Fresh mozzarella c...
# 1  [Tofu, cubed, Broccoli florets, Carrots, slice...
#
#                                         instructions  prepTimeMinutes  \
# 0  [Preheat the oven to 475°F (245°C)., Roll out ...               20
# 1  [In a wok, heat sesame oil over medium-high he...               15
#
#    cookTimeMinutes  servings difficulty  cuisine  caloriesPerServing  \
# 0               15         4       Easy  Italian                 300
# 1               20         3     Medium    Asian                 250
#
#                             tags  userId  \
# 0               [Pizza, Italian]     166
# 1  [Vegetarian, Stir-fry, Asian]     143
#
#                                             image  rating  reviewCount  \
# 0  https://cdn.dummyjson.com/recipe-images/1.webp     4.6           98
# ...

# %%
result = recipes_df [ ["caloriesPerServing", "prepTimeMinutes"] ]
type(result)
# Out:
# pandas.core.frame.DataFrame

# %%
short_recipes_df = recipes_df[['name', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
       'caloriesPerServing', 'userId', 'rating', 'reviewCount']]
short_recipes_df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
#
#    caloriesPerServing  userId  rating  reviewCount
# 0                 300     166     4.6           98
# 1                 250     143     4.7           26

# %%
sorted(short_recipes_df["cookTimeMinutes"].unique())
# Out:
# [np.int64(0),
#  np.int64(10),
#  np.int64(15),
#  np.int64(20),
#  np.int64(25),
#  np.int64(30),
#  np.int64(35),
#  np.int64(40),
#  np.int64(45)]

# %%
short_recipes_df["cookTimeMinutes"] > 30
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28    False
# 29    False
# Name: cookTimeMinutes, dtype: bool

# %%
short_recipes_df[short_recipes_df["cookTimeMinutes"] > 30]
# Out:
#                name  prepTimeMinutes  cookTimeMinutes  servings  \
# 10  Chicken Biryani               30               45         6
# 12       Aloo Keema               25               35         5
# 18   Greek Moussaka               45               45         6
# 26  Russian Borscht               30               40         6
#
#     caloriesPerServing  userId  rating  reviewCount
# 10                 550     133     5.0           32
# 12                 380     152     4.6           53
# 18                 420     173     4.3           26
# 26                 220       1     4.3           39

# %%
conditie = short_recipes_df["cookTimeMinutes"] > 30

short_recipes_df[conditie]
# Out:
#                name  prepTimeMinutes  cookTimeMinutes  servings  \
# 10  Chicken Biryani               30               45         6
# 12       Aloo Keema               25               35         5
# 18   Greek Moussaka               45               45         6
# 26  Russian Borscht               30               40         6
#
#     caloriesPerServing  userId  rating  reviewCount
# 10                 550     133     5.0           32
# 12                 380     152     4.6           53
# 18                 420     173     4.3           26
# 26                 220       1     4.3           39

# %%
conditie1 = short_recipes_df["cookTimeMinutes"] > 20
conditie2 = short_recipes_df["cookTimeMinutes"] < 30

short_recipes_df[conditie1 & conditie2]
# Out:
#                               name  prepTimeMinutes  cookTimeMinutes  \
# 4              Mango Salsa Chicken               15               25
# 15             Japanese Ramen Soup               20               25
# 19  Butter Chicken (Murgh Makhani)               30               25
#
#     servings  caloriesPerServing  userId  rating  reviewCount
# 4          3                 380      26     4.9           63
# 15         2                 480      85     4.9           38
# 19         4                 480     138     4.5           44

# %%
short_recipes_df[(short_recipes_df["cookTimeMinutes"] > 20) & (short_recipes_df["cookTimeMinutes"] < 30)]
# Out:
#                               name  prepTimeMinutes  cookTimeMinutes  \
# 4              Mango Salsa Chicken               15               25
# 15             Japanese Ramen Soup               20               25
# 19  Butter Chicken (Murgh Makhani)               30               25
#
#     servings  caloriesPerServing  userId  rating  reviewCount
# 4          3                 380      26     4.9           63
# 15         2                 480      85     4.9           38
# 19         4                 480     138     4.5           44

# %%
short_recipes_df[(short_recipes_df["cookTimeMinutes"] < 20) | (short_recipes_df["cookTimeMinutes"] > 30)]
# Out:
#                            name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0      Classic Margherita Pizza               20               15         4
# 2        Chocolate Chip Cookies               15               10        24
# 5     Quinoa Salad with Avocado               20               15         4
# 6       Tomato Basil Bruschetta               15               10         6
# 7    Beef and Broccoli Stir-Fry               20               15         4
# 8                 Caprese Salad               10                0         2
# 10              Chicken Biryani               30               45         6
# 12                   Aloo Keema               25               35         5
# 18               Greek Moussaka               45               45         6
# 21                  Mango Lassi               10                0         2
# 22             Italian Tiramisu               30                0         6
# ...

# %%
short_recipes_df["caloriesPerServing"].max()
# Out:
# np.int64(550)

# %%
short_recipes_df[ short_recipes_df["caloriesPerServing"] == short_recipes_df["caloriesPerServing"].max() ]
# Out:
#                name  prepTimeMinutes  cookTimeMinutes  servings  \
# 10  Chicken Biryani               30               45         6
# 17  Korean Bibimbap               30               20         2
#
#     caloriesPerServing  userId  rating  reviewCount
# 10                 550     133     5.0           32
# 17                 550     121     4.9           56

# %%
short_recipes_df["servings"].unique()
# Out:
# array([ 4,  3, 24,  6,  2,  5,  1])

# %%
short_recipes_df.groupby("servings").agg(['count'])
# Out:
#           name prepTimeMinutes cookTimeMinutes caloriesPerServing userId  \
#          count           count           count              count  count
# servings
# 1            2               2               2                  2      2
# 2            5               5               5                  5      5
# 3            4               4               4                  4      4
# 4           12              12              12                 12     12
# 5            1               1               1                  1      1
# 6            5               5               5                  5      5
# 24           1               1               1                  1      1
#
#          rating reviewCount
#           count       count
# servings
# 1             2           2
# 2             5           5
# 3             4           4
# 4            12          12
# 5             1           1
# 6             5           5
# 24            1           1

# %%
short_recipes_df.groupby("servings").agg(['count'])["name"]
# Out:
#           count
# servings
# 1             2
# 2             5
# 3             4
# 4            12
# 5             1
# 6             5
# 24            1

# %%
short_recipes_df.keys()
# Out:
# Index(['name', 'prepTimeMinutes', 'cookTimeMinutes', 'servings',
#        'caloriesPerServing', 'userId', 'rating', 'reviewCount'],
#       dtype='object')

# %%
new_recipes_df =  pd.DataFrame({
    'name' : ['Ciorba'], 
    'prepTimeMinutes': [30], 
    'cookTimeMinutes': [120] , 
    'servings': [ 10],
    'caloriesPerServing': [500],
    'userId' : [233], 
    'rating' : [4.9], 
    'reviewCount' : [50]
})
new_recipes_df
# Out:
#      name  prepTimeMinutes  cookTimeMinutes  servings  caloriesPerServing  \
# 0  Ciorba               30              120        10                 500
#
#    userId  rating  reviewCount
# 0     233     4.9           50

# %%
merged_df = pd.concat([new_recipes_df, short_recipes_df])
merged_df.head()
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                    Ciorba               30              120        10
# 0  Classic Margherita Pizza               20               15         4
# 1       Vegetarian Stir-Fry               15               20         3
# 2    Chocolate Chip Cookies               15               10        24
# 3     Chicken Alfredo Pasta               15               20         4
#
#    caloriesPerServing  userId  rating  reviewCount
# 0                 500     233     4.9           50
# 0                 300     166     4.6           98
# 1                 250     143     4.7           26
# 2                 150      34     4.9           13
# 3                 500     136     4.9           82

# %%
merged_df = merged_df.reset_index(drop=True)
merged_df.head(5)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                    Ciorba               30              120        10
# 1  Classic Margherita Pizza               20               15         4
# 2       Vegetarian Stir-Fry               15               20         3
# 3    Chocolate Chip Cookies               15               10        24
# 4     Chicken Alfredo Pasta               15               20         4
#
#    caloriesPerServing  userId  rating  reviewCount
# 0                 500     233     4.9           50
# 1                 300     166     4.6           98
# 2                 250     143     4.7           26
# 3                 150      34     4.9           13
# 4                 500     136     4.9           82

# %%
merged_df.rename(
    columns = {
        "prepTimeMinutes" : "prepTime",
        "cookTimeMinutes" : "cookTime"
    }
).head(2)
# Out:
#                        name  prepTime  cookTime  servings  caloriesPerServing  \
# 0                    Ciorba        30       120        10                 500
# 1  Classic Margherita Pizza        20        15         4                 300
#
#    userId  rating  reviewCount
# 0     233     4.9           50
# 1     166     4.6           98

# %%
merged_df.head(2)
# Out:
#                        name  prepTimeMinutes  cookTimeMinutes  servings  \
# 0                    Ciorba               30              120        10
# 1  Classic Margherita Pizza               20               15         4
#
#    caloriesPerServing  userId  rating  reviewCount
# 0                 500     233     4.9           50
# 1                 300     166     4.6           98

# %%
merged_df = merged_df.rename(
    columns = {
        "prepTimeMinutes" : "prepTime",
        "cookTimeMinutes" : "cookTime"
    }
)
merged_df.head(2)
# Out:
#                        name  prepTime  cookTime  servings  caloriesPerServing  \
# 0                    Ciorba        30       120        10                 500
# 1  Classic Margherita Pizza        20        15         4                 300
#
#    userId  rating  reviewCount
# 0     233     4.9           50
# 1     166     4.6           98

# %%
caloriesPerServings =  merged_df["caloriesPerServing"].unique()
caloriesPerServings.sort()
caloriesPerServings
# Out:
# array([120, 150, 180, 200, 220, 250, 280, 300, 320, 350, 380, 400, 420,
#        480, 500, 550])

# %%
merged_df["isLight"] = merged_df["caloriesPerServing"] < 250
merged_df.head()
# Out:
#                        name  prepTime  cookTime  servings  caloriesPerServing  \
# 0                    Ciorba        30       120        10                 500
# 1  Classic Margherita Pizza        20        15         4                 300
# 2       Vegetarian Stir-Fry        15        20         3                 250
# 3    Chocolate Chip Cookies        15        10        24                 150
# 4     Chicken Alfredo Pasta        15        20         4                 500
#
#    userId  rating  reviewCount  isLight
# 0     233     4.9           50    False
# 1     166     4.6           98    False
# 2     143     4.7           26    False
# 3      34     4.9           13     True
# 4     136     4.9           82    False
